# %% [markdown]
# <a href="https://colab.research.google.com/github/Sachinbhola51github/dataesetanalysis/blob/main/basicday1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hellow world")
# Out:
# hellow world

# %%
print(hellow world)
# Out:
#   File "/tmp/ipython-input-3972746045.py", line 1
#     print(hellow world)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print(10)
# Out:
# 10

# %%
print(10)
print(type(10))
# Out:
# 10
# <class 'int'>

# %%
s = "helllow world"
print(s)
# Out:
# helllow world

# %%
s.upper(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3114311927.py in <cell line: 0>()
# ----> 1 s.upper(s)
#
# TypeError: str.upper() takes no arguments (1 given)

# %%
10 + 10
# Out:
# 20
